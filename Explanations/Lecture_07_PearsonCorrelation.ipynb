# %% [markdown]
# # **Introduction**
#
# These are some examples we discussed in class. Try to solve them before looking at the answers. I use the following code to import my dataset.

# %% [markdown]
# # 1.1
#
# Load in the iris dataset and make a scatter plot of the dataset for each unique pair of dimensions.

# %% [markdown]
# #### Answer

# %%
import numpy as np
import sklearn
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
iris_dataset = load_iris()

D = iris_dataset['data']
print(D)
Y = iris_dataset['target']

# create dataframe from data in X_train
# label the columns using the strings in iris_dataset.feature_names
iris_dataframe = pd.DataFrame(D, columns=iris_dataset.feature_names)
# create a scatter matrix from the dataframe, color by y_train
pd.plotting.scatter_matrix(iris_dataframe, figsize=(10, 10),
                           marker='o', hist_kwds={'bins': 20}, s=60,
                           alpha=.8, cmap=plt.cm.brg, label=list(iris_dataset.target_names))

handles = [plt.plot([],[],color=plt.cm.brg(i/2.), ls="", marker=".", 
                    markersize=10)[0] for i in range(3)]
plt.legend(handles, list(iris_dataset.target_names), loc=(1.02,0))
plt.show()
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.2]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.6 1.4 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %% [markdown]
# # 1.2
#
# Now compute the Pearson correlation matrix of this dataset and make a plot of it labeled with the feature dimensions. Compare the values you see in this matrix with scatter plots created in 1.1.

# %% [markdown]
# #### Answer

# %%
corr = iris_dataframe.corr()
#corr.style.background_gradient(cmap='coolwarm', axis=None)
corr
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %%
import seaborn as sns
ax = sns.heatmap(corr, annot=True)
